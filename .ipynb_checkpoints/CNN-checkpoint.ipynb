# %%
#Load Tiny Imagenet Dataset

# !curl https://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from PIL import Image
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchviz import make_dot
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau
from tqdm import tqdm
import os
from torchvision import transforms

# %%
random.seed(42)
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
print(f"Using device {device}")
# Out:
# Using device cuda:3

# %%
os.listdir("tiny-imagenet-200")
# Out:
# ['wnids.txt', 'train', 'test', 'val', 'words.txt']

# %%
with open("tiny-imagenet-200/words.txt") as f:
    words = f.read().strip().split("\n")
    word_dict = {}
    for word in words:
        word_id, word = word.split("\t")
        word_dict[word_id] = word

print(len(word_dict))
# Out:
# 82115

# %%
random.sample(list(word_dict.items()), 5)
# Out:
# [('n02736396', 'areaway'),
#  ('n00646504', 'scatology'),
#  ('n06681035', 'carbon process'),
#  ('n05855904', 'term'),
#  ('n05298159', 'primordium, anlage')]

# %%
with open("tiny-imagenet-200/wnids.txt") as f:
    wnids = f.read().strip().split("\n")
print(wnids[:5])
print(len(wnids))
# Out:
# ['n02124075', 'n04067472', 'n04540053', 'n04099969', 'n07749582']
# 200

# %%
image_dirs = [os.path.join("tiny-imagenet-200/train", wnid, "images") for wnid in wnids]
image_files = [os.path.join(img_dir, img_file) for img_dir in image_dirs for img_file in os.listdir(img_dir)]
image_files[:5]
# Out:
# ['tiny-imagenet-200/train/n02124075/images/n02124075_272.JPEG',
#  'tiny-imagenet-200/train/n02124075/images/n02124075_346.JPEG',
#  'tiny-imagenet-200/train/n02124075/images/n02124075_94.JPEG',
#  'tiny-imagenet-200/train/n02124075/images/n02124075_0.JPEG',
#  'tiny-imagenet-200/train/n02124075/images/n02124075_260.JPEG']

# %%
fig, ax = plt.subplots(5, 3, figsize=(15,9))
for i in range(5):
    for j in range(3):
        random_idx = random.randint(0, len(image_files) - 1)
        img_path = image_files[random_idx]
        img = mpimg.imread(img_path)
        print(img.shape)
        ax[i, j].imshow(img)
        ax[i, j].axis('off')
        wnid = img_path.split(os.sep)[-3]
        ax[i, j].set_title(f"{word_dict[wnid].split(',')[:2]} ({wnid})")
# Out:
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)

# %%
class TinyImageNetDataset(Dataset):
    def __init__(self, root_dir, split="train", transform=None):
        self.root_dir = root_dir
        self.split = split
        self.transform = transform

        self.image_paths = []
        self.labels = []
        self.class_to_idx = {}

        # Load class list
        wnids_path = os.path.join(root_dir, "wnids.txt")
        with open(wnids_path, "r") as f:
            wnids = [x.strip() for x in f.readlines()]
        self.class_to_idx = {wnid: i for i, wnid in enumerate(wnids)}

        if split == "train":
            self._load_train()
        else:
            self._load_val()

    def _load_train(self):
        train_dir = os.path.join(self.root_dir, "train")
        for wnid in os.listdir(train_dir):
            img_dir = os.path.join(train_dir, wnid, "images")
            if not os.path.isdir(img_dir):
                continue
            for fname in os.listdir(img_dir):
                if fname.endswith(".JPEG"):
                    self.image_paths.append(os.path.join(img_dir, fname))
                    self.labels.append(self.class_to_idx[wnid])

    def _load_val(self):
        val_dir = os.path.join(self.root_dir, "val")
        anno_path = os.path.join(val_dir, "val_annotations.txt")
        img_dir = os.path.join(val_dir, "images")

        # Parse annotations
        annotations = {}
        with open(anno_path, "r") as f:
            for line in f.readlines():
                parts = line.strip().split("\t")
                if len(parts) >= 2:
                    annotations[parts[0]] = parts[1]

        for fname in os.listdir(img_dir):
            if fname.endswith(".JPEG") and fname in annotations:
                wnid = annotations[fname]
                if wnid in self.class_to_idx:
                    self.image_paths.append(os.path.join(img_dir, fname))
                    self.labels.append(self.class_to_idx[wnid])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
from torchvision import transforms

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(64, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.02),
    transforms.ToTensor(),
    transforms.Normalize((0.480, 0.448, 0.397), (0.277, 0.269, 0.282)),
    transforms.RandomErasing(p=0.25, scale=(0.02, 0.25), ratio=(0.3, 3.3))
])

# val_transform = transforms.Compose([
#     transforms.Resize(64),
#     transforms.CenterCrop(64),
#     transforms.ToTensor(),
#     transforms.Normalize((0.480, 0.448, 0.397), (0.277, 0.269, 0.282))
# ])
train_dataset = TinyImageNetDataset(root_dir="tiny-imagenet-200", split="train", transform=train_transform)
val_dataset = TinyImageNetDataset(root_dir="tiny-imagenet-200", split="val", transform=transforms.ToTensor())

# %%
class CNNBlock(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(0.1)

    def forward(self, x):
        return self.relu(self.bn(self.conv(x)))


class CustomCNN(nn.Module):
    def __init__(self, architecture_config, in_channels=3, input_size=64, num_classes=200, fc_layers=None, dropout=0.5, **kwargs):
        super(CustomCNN, self).__init__()
        self.architecture = architecture_config
        self.in_channels = in_channels
        self.input_size = input_size
        self.num_classes = num_classes
        
        self.network = self._create_conv_layers(self.architecture)
        
        self.fc_layers = fc_layers if fc_layers else [512]
        self.flat_size = self._calculate_flat_size()
        self.dropout = dropout # Dropout for FC layers
        
        self.fcs = self._create_fc_layers(**kwargs)


    def forward(self,x):
        x = self.network(x)
        return self.fcs(torch.flatten(x, start_dim=1))
    
    def _calculate_flat_size(self):
        """Calculate flattened size by passing dummy input through conv layers"""
        dummy_input = torch.zeros(1, self.in_channels, self.input_size, self.input_size)
        dummy_output = self.network(dummy_input)
        return dummy_output.view(1, -1).shape[1]
    
    def _create_conv_layers(self, architecture):
        layers = []
        in_channels = self.in_channels
        
        for x in architecture:
            if type(x) == tuple:
                layers += [
                    CNNBlock(in_channels, out_channels = x[1], kernel_size=x[0], stride=x[2], padding=x[3],)]
                in_channels = x[1]

            if type(x) == str:
                layers += [
                    nn.MaxPool2d(kernel_size=2, stride=2)]

            if type(x) == list:
                conv1 = x[0]
                conv2 = x[1]
                num_repeats = x[2]

                for _ in range(num_repeats):
                    layers += [
                        CNNBlock(in_channels, out_channels = conv1[1], kernel_size= conv1[0], stride=conv1[2], padding=conv1[3],)]
                    layers += [
                        CNNBlock(conv1[1], out_channels = conv2[1], kernel_size= conv2[0], stride=conv2[2], padding=conv2[3],)]
                    in_channels = conv2[1]
        return nn.Sequential(*layers)
    
    def _create_fc_layers(self):
        """Build FC layers dynamically based on flat_size and fc_layers config"""
        layers = []
        layer_sizes = [self.flat_size] + self.fc_layers + [self.num_classes]
        
        # Create all layers except the last one with activation and dropout
        for i in range(len(layer_sizes) - 2):
            layers.append(nn.Linear(layer_sizes[i], layer_sizes[i+1]))
            layers.append(nn.LeakyReLU(0.1))
            layers.append(nn.Dropout(self.dropout))
        
        # Last layer: no activation (will use with CrossEntropyLoss)
        layers.append(nn.Linear(layer_sizes[-2], layer_sizes[-1]))
        
        return nn.Sequential(*layers)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler=None, num_epochs=5, device='cuda'):
    model.to(device)

    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        print(f"\nEpoch [{epoch+1}/{num_epochs}]")
        model.train()
        running_loss = 0.0

        # --- Training Loop with tqdm ---
        train_pbar = tqdm(train_loader, desc='Training', leave=False)
        for images, labels in train_pbar:
            images, labels = images.to(device), labels.to(device)

            # Forward
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            train_pbar.set_postfix(loss=loss.item())

        avg_train_loss = running_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # --- Validation Loop ---
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        val_pbar = tqdm(val_loader, desc='Validating', leave=False)
        with torch.no_grad():
            for images, labels in val_pbar:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                # Accuracy
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        val_accuracy = 100 * correct / total

        # --- Scheduler Step ---
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(avg_val_loss)
            else:
                scheduler.step()

        current_lr = optimizer.param_groups[0]['lr']

        print(f"Epoch [{epoch+1}/{num_epochs}] "
              f"Train Loss: {avg_train_loss:.4f} | "
              f"Val Loss: {avg_val_loss:.4f} | "
              f"Val Acc: {val_accuracy:.2f}% | "
              f"LR: {current_lr:.6f}")

    print("Training complete!")
    return train_losses, val_losses

# %%
""" 
Information about architecture config:
Tuple is structured by (kernel_size, filters, stride, padding) 
"M" is simply maxpooling with stride 2x2 and kernel 2x2
List is structured by tuples and lastly int with number of repeats
"""


TINY_IMAGENET_ARCH = [
    (3, 64, 1, 1),   # 64x64 -> 64x64
    (3, 64, 1, 1),
    "M",             # 64 -> 32
    (3, 128, 1, 1),
    (3, 128, 1, 1),
    "M",             # 32 -> 16
    (3, 256, 1, 1),
    (3, 256, 1, 1),
    (1, 256, 1, 0),  # bottleneck
    "M",             # 16 -> 8
    (3, 512, 1, 1),
    (1, 512, 1, 0),  # bottleneck
    "M",             # 8 -> 4
]

TINY_IMAGENET_FC_LAYERS = [512, 256]

# %%
train_loader = DataLoader(train_dataset, batch_size=1024, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=1024, shuffle=False, num_workers=4)

# %%
model_Adam = CustomCNN(
    architecture_config=TINY_IMAGENET_ARCH,
    in_channels=3,
    input_size=64,
    num_classes=200,
    fc_layers=TINY_IMAGENET_FC_LAYERS
)


criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_Adam.parameters(), lr=0.001)

num_epochs = 100


train_losses, val_losses = train_model(model_Adam, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer, num_epochs=num_epochs)

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.savefig('loss_plot_model.png', dpi=300, bbox_inches='tight')  # Saves as PNG with good quality
plt.show()
# Out:
# Epoch [1/100]
# Epoch [1/100] Train Loss: 5.1734 | Val Loss: 4.9507 | Val Acc: 2.37% | LR: 0.001000
#
# Epoch [2/100]
# Epoch [2/100] Train Loss: 4.7313 | Val Loss: 4.5110 | Val Acc: 5.97% | LR: 0.001000
#
# Epoch [3/100]
# Epoch [3/100] Train Loss: 4.2593 | Val Loss: 4.1562 | Val Acc: 9.61% | LR: 0.001000
#
# Epoch [4/100]
# Epoch [4/100] Train Loss: 3.9229 | Val Loss: 3.8819 | Val Acc: 14.83% | LR: 0.001000
#
# Epoch [5/100]
# Epoch [5/100] Train Loss: 3.6907 | Val Loss: 3.7900 | Val Acc: 15.51% | LR: 0.001000
#
# Epoch [6/100]
# Epoch [6/100] Train Loss: 3.5043 | Val Loss: 3.5366 | Val Acc: 19.40% | LR: 0.001000
#
# Epoch [7/100]
# Epoch [7/100] Train Loss: 3.3406 | Val Loss: 3.3598 | Val Acc: 22.31% | LR: 0.001000
#
# Epoch [8/100]
# Epoch [8/100] Train Loss: 3.1989 | Val Loss: 3.1040 | Val Acc: 27.00% | LR: 0.001000
#
# Epoch [9/100]
# Epoch [9/100] Train Loss: 3.0644 | Val Loss: 3.1837 | Val Acc: 26.62% | LR: 0.001000
#
# Epoch [10/100]
# Epoch [10/100] Train Loss: 2.9359 | Val Loss: 3.2109 | Val Acc: 26.06% | LR: 0.001000
#
# Epoch [11/100]
# Epoch [11/100] Train Loss: 2.8085 | Val Loss: 2.9658 | Val Acc: 30.30% | LR: 0.001000
#
# Epoch [12/100]
# Epoch [12/100] Train Loss: 2.6954 | Val Loss: 3.0083 | Val Acc: 30.81% | LR: 0.001000
#
# Epoch [13/100]
# Epoch [13/100] Train Loss: 2.5785 | Val Loss: 2.8468 | Val Acc: 32.36% | LR: 0.001000
#
# Epoch [14/100]
# Epoch [14/100] Train Loss: 2.4647 | Val Loss: 2.8046 | Val Acc: 34.55% | LR: 0.001000
#
# Epoch [15/100]
# Epoch [15/100] Train Loss: 2.3501 | Val Loss: 2.8963 | Val Acc: 34.13% | LR: 0.001000
#
# Epoch [16/100]
# Epoch [16/100] Train Loss: 2.2399 | Val Loss: 2.7594 | Val Acc: 35.10% | LR: 0.001000
#
# Epoch [17/100]
# Epoch [17/100] Train Loss: 2.1218 | Val Loss: 2.7002 | Val Acc: 36.45% | LR: 0.001000
#
# Epoch [18/100]
# Epoch [18/100] Train Loss: 2.0125 | Val Loss: 2.6883 | Val Acc: 36.71% | LR: 0.001000
#
# Epoch [19/100]
# Epoch [19/100] Train Loss: 1.8986 | Val Loss: 2.5193 | Val Acc: 40.12% | LR: 0.001000
#
# Epoch [20/100]
# Epoch [20/100] Train Loss: 1.7768 | Val Loss: 2.7506 | Val Acc: 37.84% | LR: 0.001000
#
# Epoch [21/100]
# Epoch [21/100] Train Loss: 1.6847 | Val Loss: 2.7572 | Val Acc: 37.18% | LR: 0.001000
#
# Epoch [22/100]
# Epoch [22/100] Train Loss: 1.5790 | Val Loss: 2.7872 | Val Acc: 37.25% | LR: 0.001000
#
# Epoch [23/100]
# Epoch [23/100] Train Loss: 1.4539 | Val Loss: 2.6500 | Val Acc: 41.00% | LR: 0.001000
#
# Epoch [24/100]
# Epoch [24/100] Train Loss: 1.3552 | Val Loss: 2.6892 | Val Acc: 40.16% | LR: 0.001000
#
# Epoch [25/100]
# Epoch [25/100] Train Loss: 1.2444 | Val Loss: 2.9510 | Val Acc: 37.76% | LR: 0.001000
#
# Epoch [26/100]
# Epoch [26/100] Train Loss: 1.1523 | Val Loss: 2.8473 | Val Acc: 40.25% | LR: 0.001000
#
# Epoch [27/100]
# Epoch [27/100] Train Loss: 1.0557 | Val Loss: 2.9569 | Val Acc: 39.15% | LR: 0.001000
#
# Epoch [28/100]
# Epoch [28/100] Train Loss: 0.9737 | Val Loss: 3.2077 | Val Acc: 37.89% | LR: 0.001000
#
# Epoch [29/100]
# Epoch [29/100] Train Loss: 0.9042 | Val Loss: 3.2351 | Val Acc: 38.97% | LR: 0.001000
#
# Epoch [30/100]
#
# Epoch [53/100]
# Epoch [53/100] Train Loss: 0.2753 | Val Loss: 4.9455 | Val Acc: 37.90% | LR: 0.001000
#
# Epoch [54/100]
# Epoch [54/100] Train Loss: 0.2659 | Val Loss: 4.7646 | Val Acc: 37.53% | LR: 0.001000
#
# Epoch [55/100]
# Epoch [55/100] Train Loss: 0.2563 | Val Loss: 4.9985 | Val Acc: 37.20% | LR: 0.001000
#
# Epoch [56/100]
# Epoch [56/100] Train Loss: 0.2455 | Val Loss: 4.8987 | Val Acc: 36.50% | LR: 0.001000
#
# Epoch [57/100]
# Epoch [57/100] Train Loss: 0.2448 | Val Loss: 4.8168 | Val Acc: 38.16% | LR: 0.001000
#
# Epoch [58/100]
# Epoch [58/100] Train Loss: 0.2373 | Val Loss: 4.8676 | Val Acc: 37.92% | LR: 0.001000
#
# Epoch [59/100]
# Epoch [59/100] Train Loss: 0.2351 | Val Loss: 5.2291 | Val Acc: 38.10% | LR: 0.001000
#
# Epoch [60/100]
# Epoch [60/100] Train Loss: 0.2426 | Val Loss: 5.2433 | Val Acc: 36.54% | LR: 0.001000
#
# Epoch [61/100]
# Epoch [61/100] Train Loss: 0.2257 | Val Loss: 5.2336 | Val Acc: 36.90% | LR: 0.001000
#
# Epoch [62/100]
# Epoch [62/100] Train Loss: 0.2141 | Val Loss: 5.3258 | Val Acc: 37.11% | LR: 0.001000
#
# Epoch [63/100]
# Epoch [63/100] Train Loss: 0.2273 | Val Loss: 5.1214 | Val Acc: 37.83% | LR: 0.001000
#
# Epoch [64/100]
# Epoch [64/100] Train Loss: 0.2223 | Val Loss: 5.2054 | Val Acc: 37.27% | LR: 0.001000
#
# Epoch [65/100]
# Epoch [65/100] Train Loss: 0.2150 | Val Loss: 5.2318 | Val Acc: 37.98% | LR: 0.001000
#
# Epoch [66/100]
# Epoch [66/100] Train Loss: 0.2106 | Val Loss: 5.3900 | Val Acc: 36.42% | LR: 0.001000
#
# Epoch [67/100]
# Epoch [67/100] Train Loss: 0.2068 | Val Loss: 5.2733 | Val Acc: 38.00% | LR: 0.001000
#
# Epoch [68/100]
# Epoch [68/100] Train Loss: 0.2177 | Val Loss: 5.3471 | Val Acc: 36.99% | LR: 0.001000
#
# Epoch [69/100]
# Epoch [69/100] Train Loss: 0.2058 | Val Loss: 5.3042 | Val Acc: 37.24% | LR: 0.001000
#
# Epoch [70/100]
# Epoch [70/100] Train Loss: 0.2038 | Val Loss: 5.0828 | Val Acc: 37.75% | LR: 0.001000
#
# Epoch [71/100]
# Epoch [71/100] Train Loss: 0.1932 | Val Loss: 5.1629 | Val Acc: 37.19% | LR: 0.001000
#
# Epoch [72/100]
# Epoch [72/100] Train Loss: 0.1922 | Val Loss: 5.4742 | Val Acc: 35.72% | LR: 0.001000
#
# Epoch [73/100]
# Epoch [73/100] Train Loss: 0.1832 | Val Loss: 5.2613 | Val Acc: 37.78% | LR: 0.001000
#
# Epoch [74/100]
# Epoch [74/100] Train Loss: 0.1887 | Val Loss: 5.3379 | Val Acc: 37.65% | LR: 0.001000
#
# Epoch [75/100]
# Epoch [97/100] Train Loss: 0.1527 | Val Loss: 5.7126 | Val Acc: 37.25% | LR: 0.001000
#
# Epoch [98/100]
# Epoch [98/100] Train Loss: 0.1420 | Val Loss: 5.7675 | Val Acc: 37.84% | LR: 0.001000
#
# Epoch [99/100]
# Epoch [99/100] Train Loss: 0.1455 | Val Loss: 5.8944 | Val Acc: 36.80% | LR: 0.001000
#
# Epoch [100/100]
# Epoch [100/100] Train Loss: 0.1464 | Val Loss: 5.7176 | Val Acc: 38.53% | LR: 0.001000
# Training complete!

# %%
model_Adam_sche = CustomCNN(
    architecture_config=TINY_IMAGENET_ARCH,
    in_channels=3,
    input_size=64,
    num_classes=200,
    fc_layers=TINY_IMAGENET_FC_LAYERS
)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_Adam_sche.parameters(), lr=0.001)

from torch.optim.lr_scheduler import StepLR
scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

num_epochs = 100



train_losses, val_losses = train_model(model_Adam_sche, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer, scheduler=scheduler, num_epochs=num_epochs)

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.savefig('loss_plot_model_Adam_sche.png', dpi=300, bbox_inches='tight')  # Saves as PNG with good quality
plt.show()
# Out:
# Epoch [1/100]
# Epoch [1/100] Train Loss: 5.1619 | Val Loss: 4.8799 | Val Acc: 2.24% | LR: 0.001000
#
# Epoch [2/100]
# Epoch [2/100] Train Loss: 4.6474 | Val Loss: 4.3509 | Val Acc: 7.50% | LR: 0.001000
#
# Epoch [3/100]
# Epoch [3/100] Train Loss: 4.1753 | Val Loss: 4.0948 | Val Acc: 10.75% | LR: 0.001000
#
# Epoch [4/100]
# Epoch [4/100] Train Loss: 3.8708 | Val Loss: 3.7611 | Val Acc: 16.13% | LR: 0.001000
#
# Epoch [5/100]
# Epoch [5/100] Train Loss: 3.6349 | Val Loss: 3.6306 | Val Acc: 18.09% | LR: 0.001000
#
# Epoch [6/100]
# Epoch [6/100] Train Loss: 3.4461 | Val Loss: 3.3480 | Val Acc: 22.56% | LR: 0.001000
#
# Epoch [7/100]
# Epoch [7/100] Train Loss: 3.2938 | Val Loss: 3.3448 | Val Acc: 22.64% | LR: 0.001000
#
# Epoch [8/100]
# Epoch [8/100] Train Loss: 3.1620 | Val Loss: 3.1611 | Val Acc: 25.72% | LR: 0.001000
#
# Epoch [9/100]
# Epoch [9/100] Train Loss: 3.0229 | Val Loss: 2.9784 | Val Acc: 28.95% | LR: 0.001000
#
# Epoch [10/100]
# Epoch [10/100] Train Loss: 2.9039 | Val Loss: 3.6463 | Val Acc: 21.21% | LR: 0.001000
#
# Epoch [11/100]
# Epoch [11/100] Train Loss: 2.7810 | Val Loss: 2.9351 | Val Acc: 30.76% | LR: 0.001000
#
# Epoch [12/100]
# Epoch [12/100] Train Loss: 2.6634 | Val Loss: 2.8034 | Val Acc: 33.92% | LR: 0.001000
#
# Epoch [13/100]
# Epoch [13/100] Train Loss: 2.5519 | Val Loss: 2.7896 | Val Acc: 33.88% | LR: 0.001000
#
# Epoch [14/100]
# Epoch [14/100] Train Loss: 2.4262 | Val Loss: 2.6272 | Val Acc: 36.90% | LR: 0.001000
#
# Epoch [15/100]
# Epoch [15/100] Train Loss: 2.3228 | Val Loss: 2.9091 | Val Acc: 32.38% | LR: 0.001000
#
# Epoch [83/100]
# Epoch [83/100] Train Loss: 0.1705 | Val Loss: 5.5540 | Val Acc: 37.55% | LR: 0.001000
#
# Epoch [84/100]
# Epoch [84/100] Train Loss: 0.1724 | Val Loss: 5.3224 | Val Acc: 37.73% | LR: 0.001000
#
# Epoch [85/100]
# Epoch [85/100] Train Loss: 0.1696 | Val Loss: 5.7567 | Val Acc: 37.05% | LR: 0.001000
#
# Epoch [86/100]
# Epoch [86/100] Train Loss: 0.1678 | Val Loss: 5.3857 | Val Acc: 37.87% | LR: 0.001000
#
# Epoch [87/100]
# Epoch [87/100] Train Loss: 0.1614 | Val Loss: 5.6859 | Val Acc: 38.12% | LR: 0.001000
#
# Epoch [88/100]
# Epoch [88/100] Train Loss: 0.1635 | Val Loss: 5.5105 | Val Acc: 37.94% | LR: 0.001000
#
# Epoch [89/100]
# Epoch [89/100] Train Loss: 0.1554 | Val Loss: 5.8134 | Val Acc: 37.79% | LR: 0.001000
#
# Epoch [90/100]
# Epoch [90/100] Train Loss: 0.1656 | Val Loss: 5.8122 | Val Acc: 37.56% | LR: 0.001000
#
# Epoch [91/100]
# Epoch [91/100] Train Loss: 0.1536 | Val Loss: 5.7391 | Val Acc: 37.44% | LR: 0.001000
#
# Epoch [92/100]
# Epoch [92/100] Train Loss: 0.1541 | Val Loss: 5.8419 | Val Acc: 37.81% | LR: 0.001000
#
# Epoch [93/100]
# Epoch [93/100] Train Loss: 0.1524 | Val Loss: 5.8429 | Val Acc: 37.84% | LR: 0.001000
#
# Epoch [94/100]
# Epoch [94/100] Train Loss: 0.1534 | Val Loss: 5.8108 | Val Acc: 37.96% | LR: 0.001000
#
# Epoch [95/100]
# Epoch [95/100] Train Loss: 0.1490 | Val Loss: 5.8227 | Val Acc: 38.20% | LR: 0.001000
#
# Epoch [96/100]
# Epoch [96/100] Train Loss: 0.1494 | Val Loss: 5.6898 | Val Acc: 38.11% | LR: 0.001000
#
# Epoch [97/100]
# Epoch [97/100] Train Loss: 0.1476 | Val Loss: 5.7639 | Val Acc: 37.29% | LR: 0.001000
#
# Epoch [98/100]
# Epoch [98/100] Train Loss: 0.1473 | Val Loss: 5.9393 | Val Acc: 38.06% | LR: 0.001000
#
# Epoch [99/100]
# Epoch [99/100] Train Loss: 0.1479 | Val Loss: 5.9835 | Val Acc: 37.90% | LR: 0.001000
#
# Epoch [100/100]
# Epoch [100/100] Train Loss: 0.1495 | Val Loss: 5.8637 | Val Acc: 38.04% | LR: 0.001000
# Training complete!

# %%
model_Adam_rop = CustomCNN(
    architecture_config=TINY_IMAGENET_ARCH,
    in_channels=3,
    input_size=64,
    num_classes=200,
    fc_layers=TINY_IMAGENET_FC_LAYERS
)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_Adam_rop.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, step_size=5)

num_epochs = 100



train_losses, val_losses = train_model(model_Adam_rop, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer, scheduler=scheduler, num_epochs=num_epochs)

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.savefig('loss_plot_model_Adam_rop.png', dpi=300, bbox_inches='tight')  # Saves as PNG with good quality
plt.show()
# Out:
# Epoch [1/100]
# Epoch [1/100] Train Loss: 5.1782 | Val Loss: 4.8920 | Val Acc: 2.63% | LR: 0.001000
#
# Epoch [2/100]
# Epoch [2/100] Train Loss: 4.7244 | Val Loss: 4.6716 | Val Acc: 5.11% | LR: 0.001000
#
# Epoch [3/100]
# Epoch [3/100] Train Loss: 4.2599 | Val Loss: 4.1634 | Val Acc: 9.66% | LR: 0.001000
#
# Epoch [4/100]
# Epoch [4/100] Train Loss: 3.9338 | Val Loss: 3.7213 | Val Acc: 15.99% | LR: 0.001000
#
# Epoch [5/100]
# Epoch [5/100] Train Loss: 3.6756 | Val Loss: 3.5101 | Val Acc: 20.10% | LR: 0.001000
#
# Epoch [6/100]
# Epoch [6/100] Train Loss: 3.4811 | Val Loss: 3.5030 | Val Acc: 20.28% | LR: 0.001000
#
# Epoch [7/100]
# Epoch [7/100] Train Loss: 3.3131 | Val Loss: 3.3437 | Val Acc: 23.13% | LR: 0.001000
#
# Epoch [8/100]
# Epoch [8/100] Train Loss: 3.1725 | Val Loss: 3.1664 | Val Acc: 26.65% | LR: 0.001000
#
# Epoch [9/100]
# Epoch [9/100] Train Loss: 3.0423 | Val Loss: 2.9424 | Val Acc: 30.60% | LR: 0.001000
#
# Epoch [10/100]
# Epoch [10/100] Train Loss: 2.9079 | Val Loss: 2.9494 | Val Acc: 31.10% | LR: 0.001000
#
# Epoch [11/100]
# Epoch [11/100] Train Loss: 2.7798 | Val Loss: 2.8523 | Val Acc: 32.83% | LR: 0.001000
#
# Epoch [12/100]
# Epoch [12/100] Train Loss: 2.6644 | Val Loss: 2.7476 | Val Acc: 34.09% | LR: 0.001000
#
# Epoch [13/100]
# Epoch [13/100] Train Loss: 2.5544 | Val Loss: 2.7998 | Val Acc: 33.52% | LR: 0.001000
#
# Epoch [14/100]
# Epoch [14/100] Train Loss: 2.4366 | Val Loss: 2.6508 | Val Acc: 36.60% | LR: 0.001000
#
# Epoch [15/100]
# Epoch [15/100] Train Loss: 2.3293 | Val Loss: 2.6490 | Val Acc: 36.10% | LR: 0.001000
#
# Epoch [16/100]
# Epoch [16/100] Train Loss: 2.2099 | Val Loss: 2.5991 | Val Acc: 38.51% | LR: 0.001000
#
# Epoch [17/100]
# Epoch [17/100] Train Loss: 2.0934 | Val Loss: 2.5206 | Val Acc: 39.08% | LR: 0.001000
#
# Epoch [18/100]
# Epoch [18/100] Train Loss: 1.9753 | Val Loss: 2.5735 | Val Acc: 39.06% | LR: 0.001000
#
# Epoch [19/100]
# Epoch [19/100] Train Loss: 1.8654 | Val Loss: 2.5543 | Val Acc: 39.99% | LR: 0.001000
#
# Epoch [20/100]
# Epoch [20/100] Train Loss: 1.7537 | Val Loss: 2.6059 | Val Acc: 39.60% | LR: 0.001000
#
# Epoch [21/100]
# Epoch [21/100] Train Loss: 1.6412 | Val Loss: 2.8358 | Val Acc: 37.25% | LR: 0.001000
#
# Epoch [22/100]
# Epoch [22/100] Train Loss: 1.5264 | Val Loss: 2.6446 | Val Acc: 40.37% | LR: 0.001000
#
# Epoch [23/100]
# Epoch [90/100] Train Loss: 0.1582 | Val Loss: 5.4188 | Val Acc: 38.58% | LR: 0.001000
#
# Epoch [91/100]
# Epoch [91/100] Train Loss: 0.1593 | Val Loss: 5.6291 | Val Acc: 38.23% | LR: 0.001000
#
# Epoch [92/100]
# Epoch [92/100] Train Loss: 0.1585 | Val Loss: 5.6072 | Val Acc: 38.39% | LR: 0.001000
#
# Epoch [93/100]
# Epoch [93/100] Train Loss: 0.1588 | Val Loss: 5.6789 | Val Acc: 37.81% | LR: 0.001000
#
# Epoch [94/100]
# Epoch [94/100] Train Loss: 0.1530 | Val Loss: 5.6503 | Val Acc: 38.16% | LR: 0.001000
#
# Epoch [95/100]
# Epoch [95/100] Train Loss: 0.1539 | Val Loss: 5.7850 | Val Acc: 37.56% | LR: 0.001000
#
# Epoch [96/100]
# Epoch [96/100] Train Loss: 0.1549 | Val Loss: 5.6956 | Val Acc: 37.97% | LR: 0.001000
#
# Epoch [97/100]
# Epoch [97/100] Train Loss: 0.1427 | Val Loss: 5.8262 | Val Acc: 37.54% | LR: 0.001000
#
# Epoch [98/100]
# Epoch [98/100] Train Loss: 0.1479 | Val Loss: 5.6216 | Val Acc: 37.75% | LR: 0.001000
#
# Epoch [99/100]
# Epoch [99/100] Train Loss: 0.1474 | Val Loss: 5.5471 | Val Acc: 37.75% | LR: 0.001000
#
# Epoch [100/100]
# Epoch [100/100] Train Loss: 0.1393 | Val Loss: 5.7352 | Val Acc: 38.06% | LR: 0.001000
# Training complete!

# %%
model_sgd = CustomCNN(
    architecture_config=TINY_IMAGENET_ARCH,
    in_channels=3,
    input_size=64,
    num_classes=200,
    fc_layers=TINY_IMAGENET_FC_LAYERS
)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_sgd.parameters(), lr=0.001)

num_epochs = 5



train_losses, val_losses = train_model(model_sgd, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer, num_epochs=num_epochs)

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.savefig('loss_plot_model_Adam_rop.png', dpi=300, bbox_inches='tight')  # Saves as PNG with good quality
plt.show()
# Out:
# Epoch [1/5]
# Epoch [1/5] Train Loss: 5.3172 | Val Loss: 5.3004 | Val Acc: 0.49% | LR: 0.001000
#
# Epoch [2/5]
# Epoch [2/5] Train Loss: 5.3084 | Val Loss: 5.2998 | Val Acc: 0.43% | LR: 0.001000
#
# Epoch [3/5]
# Epoch [3/5] Train Loss: 5.3047 | Val Loss: 5.2995 | Val Acc: 0.40% | LR: 0.001000
#
# Epoch [4/5]
# Epoch [4/5] Train Loss: 5.3008 | Val Loss: 5.2993 | Val Acc: 0.37% | LR: 0.001000
#
# Epoch [5/5]
# Epoch [5/5] Train Loss: 5.2994 | Val Loss: 5.2991 | Val Acc: 0.41% | LR: 0.001000
# Training complete!

# %%
model_sgd_sche = CustomCNN(
    architecture_config=TINY_IMAGENET_ARCH,
    in_channels=3,
    input_size=64,
    num_classes=200,
    fc_layers=TINY_IMAGENET_FC_LAYERS
)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_sgd.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=5)

num_epochs = 20



train_losses, val_losses = train_model(model_sgd_sche, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer, scheduler=scheduler, num_epochs=num_epochs)

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.savefig('loss_plot_model_sgd_sche.png', dpi=300, bbox_inches='tight')  # Saves as PNG with good quality
plt.show()
# Out:
# Epoch [1/20]
# Epoch [1/20] Train Loss: 5.3277 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.001000
#
# Epoch [2/20]
# Epoch [2/20] Train Loss: 5.3279 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.001000
#
# Epoch [3/20]
# Epoch [3/20] Train Loss: 5.3272 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.001000
#
# Epoch [4/20]
# Epoch [4/20] Train Loss: 5.3272 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.001000
#
# Epoch [5/20]
# Epoch [5/20] Train Loss: 5.3293 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000500
#
# Epoch [6/20]
# Epoch [6/20] Train Loss: 5.3276 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.000500
#
# Epoch [7/20]
# Epoch [7/20] Train Loss: 5.3261 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.000500
#
# Epoch [8/20]
# Epoch [8/20] Train Loss: 5.3281 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000500
#
# Epoch [9/20]
# Epoch [9/20] Train Loss: 5.3267 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000500
#
# Epoch [10/20]
# Epoch [10/20] Train Loss: 5.3280 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000250
#
# Epoch [11/20]
# Epoch [11/20] Train Loss: 5.3267 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.000250
#
# Epoch [12/20]
# Epoch [12/20] Train Loss: 5.3284 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.000250
#
# Epoch [13/20]
# Epoch [13/20] Train Loss: 5.3267 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000250
#
# Epoch [14/20]
# Epoch [14/20] Train Loss: 5.3273 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.000250
#
# Epoch [15/20]
# Epoch [15/20] Train Loss: 5.3275 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000125
#
# Epoch [16/20]
# Epoch [16/20] Train Loss: 5.3278 | Val Loss: 5.3014 | Val Acc: 0.47% | LR: 0.000125
#
# Epoch [17/20]
# Epoch [17/20] Train Loss: 5.3273 | Val Loss: 5.3014 | Val Acc: 0.47% | LR: 0.000125
#
# Epoch [18/20]
# Epoch [18/20] Train Loss: 5.3282 | Val Loss: 5.3013 | Val Acc: 0.47% | LR: 0.000125
#
# Epoch [19/20]
# Epoch [19/20] Train Loss: 5.3267 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000125
#
# Epoch [20/20]
# Epoch [20/20] Train Loss: 5.3280 | Val Loss: 5.3013 | Val Acc: 0.46% | LR: 0.000063
# Training complete!

# %%
model_sgd_sche = CustomCNN(
    architecture_config=TINY_IMAGENET_ARCH,
    in_channels=3,
    input_size=64,
    num_classes=200,
    fc_layers=TINY_IMAGENET_FC_LAYERS
)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_sgd.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer)

num_epochs = 20



train_losses, val_losses = train_model(model_sgd_sche, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer, scheduler=scheduler, num_epochs=num_epochs)

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.savefig('loss_plot_model_Adam_rop.png', dpi=300, bbox_inches='tight')  # Saves as PNG with good quality
plt.show()
# Out:
# Epoch [1/20]
# Epoch [1/20] Train Loss: 5.3239 | Val Loss: 5.3010 | Val Acc: 0.47% | LR: 0.001000
#
# Epoch [2/20]
# Epoch [2/20] Train Loss: 5.3234 | Val Loss: 5.3010 | Val Acc: 0.50% | LR: 0.001000
#
# Epoch [3/20]
# Epoch [3/20] Train Loss: 5.3235 | Val Loss: 5.3010 | Val Acc: 0.48% | LR: 0.001000
#
# Epoch [4/20]
# Epoch [4/20] Train Loss: 5.3235 | Val Loss: 5.3011 | Val Acc: 0.50% | LR: 0.001000
#
# Epoch [5/20]
# Epoch [5/20] Train Loss: 5.3231 | Val Loss: 5.3010 | Val Acc: 0.50% | LR: 0.001000
#
# Epoch [6/20]
# Epoch [6/20] Train Loss: 5.3241 | Val Loss: 5.3010 | Val Acc: 0.45% | LR: 0.001000
#
# Epoch [7/20]
# Epoch [7/20] Train Loss: 5.3246 | Val Loss: 5.3010 | Val Acc: 0.50% | LR: 0.001000
#
# Epoch [8/20]
# Epoch [8/20] Train Loss: 5.3234 | Val Loss: 5.3011 | Val Acc: 0.50% | LR: 0.001000
#
# Epoch [9/20]
# Epoch [9/20] Train Loss: 5.3244 | Val Loss: 5.3010 | Val Acc: 0.47% | LR: 0.001000
#
# Epoch [10/20]
# Epoch [10/20] Train Loss: 5.3248 | Val Loss: 5.3010 | Val Acc: 0.47% | LR: 0.001000
#
# Epoch [11/20]
# Epoch [11/20] Train Loss: 5.3249 | Val Loss: 5.3010 | Val Acc: 0.48% | LR: 0.001000
#
# Epoch [12/20]
# Epoch [12/20] Train Loss: 5.3244 | Val Loss: 5.3010 | Val Acc: 0.45% | LR: 0.000100
#
# Epoch [13/20]
# Epoch [13/20] Train Loss: 5.3239 | Val Loss: 5.3010 | Val Acc: 0.47% | LR: 0.000100
#
# Epoch [14/20]
# Epoch [14/20] Train Loss: 5.3249 | Val Loss: 5.3010 | Val Acc: 0.46% | LR: 0.000100
#
# Epoch [15/20]
# Epoch [15/20] Train Loss: 5.3246 | Val Loss: 5.3010 | Val Acc: 0.50% | LR: 0.000100
#
# Epoch [16/20]
# Epoch [16/20] Train Loss: 5.3239 | Val Loss: 5.3010 | Val Acc: 0.45% | LR: 0.000100
#
# Epoch [17/20]
# Epoch [17/20] Train Loss: 5.3230 | Val Loss: 5.3010 | Val Acc: 0.46% | LR: 0.000100
#
# Epoch [18/20]
# Epoch [18/20] Train Loss: 5.3243 | Val Loss: 5.3010 | Val Acc: 0.46% | LR: 0.000100
#
# Epoch [19/20]
# Epoch [19/20] Train Loss: 5.3237 | Val Loss: 5.3010 | Val Acc: 0.47% | LR: 0.000100
#
# Epoch [20/20]
# Epoch [20/20] Train Loss: 5.3242 | Val Loss: 5.3011 | Val Acc: 0.53% | LR: 0.000100
# Training complete!
